# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import pandas as pd

default_link = 'https://www.airbnb.com/wishlists/v/1250433647?s=67&unique_share_id=26a5887d-15af-4bc3-92ef-fa74ea9da81f'
airbnb_wishlist = default_link

# %%
print('Configuring driver...')

ops = Options()
ops.add_argument('--headless')
driver = webdriver.Chrome(options= ops)
driver.get(airbnb_wishlist)
driver.implicitly_wait(20)

# %%
df = pd.DataFrame(columns=['Name', 'Location', 'Guests', 'Bedrooms', 'Beds',
                        'Baths', 'Price (Night)', 'Price (Total)', 'Link'])
df
# Out:
# Empty DataFrame
# Columns: [Name, Location, Guests, Bedrooms, Beds, Baths, Price (Night), Price (Total), Link]
# Index: []

# %%
parent = driver.find_element(By.XPATH, '//*[@id="FMP-target"]/div[1]/div')
children = parent.find_elements(By.XPATH, '*')

links = list()

for element in children:
    link = element.find_element(By.XPATH, './/div[1]/div[1]/a').get_attribute('href')
    links.append(link)

# %%
def get_data(xpath):
    try:
        data = driver.find_element(By.XPATH, xpath).text
    except Exception as e:
        print(e)
        return 'error'
    
    return data.strip() if data else ''

# %%
for link in links:
    driver.get(link)
    data = list()
    
    print(link)

    # Put data into the frame
    data.append(get_data('//*[@id="site-content"]/div/div[1]/div[1]/div[1]/div/div/div/div/section/div[1]/span/h1'))
    data.append(driver.find_element(By.CLASS_NAME, '_9xiloll').text.strip()[:-15])  # special case for location (super host badge)
    data.append(int(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[1]/div/div[1]/div/div/section/div/div/div/div[1]/ol/li[1]/span[1]')[:-7].strip('+')))
    data.append(int(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[1]/div/div[1]/div/div/section/div/div/div/div[1]/ol/li[2]/span[2]')[:-9]))
    data.append(int(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[1]/div/div[1]/div/div/section/div/div/div/div[1]/ol/li[3]/span[2]')[:-5]))
    data.append(float(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[1]/div/div[1]/div/div/section/div/div/div/div[1]/ol/li[4]/span[2]')[:-6]))
    data.append(int(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[2]/div/div/div[1]/div/div/div/div/div/div/div[3]/div/section/div[1]/div[1]/span[1]/div/button/div')[:6].strip('$').replace('x','').replace(',','')))
    data.append(int(get_data('//*[@id="site-content"]/div/div[1]/div[3]/div/div[2]/div/div/div[1]/div/div/div/div/div/div/div[3]/div/section/div[2]/div/span[2]/span[1]').strip('$').replace(',','')))
    data.append(link)

    df.loc[len(df)] = data

df
# Out:
# https://www.airbnb.com/rooms/54214255?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/52596438?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/820527439800540131?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/714929118776101156?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/46754338?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/786222532397915594?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/20723446?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/30565057?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/30566829?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/49858641?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/779058730035283861?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/808196038616551435?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/821144377638208163?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/556233449864550322?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms/802861092605859402?adults=10&children=0&infants=0&pets=0&check_in=2023-06-24&check_out=2023-07-01&previous_page_section_name=1000
# https://www.airbnb.com/rooms
# 20               Jacksonville, Florida      15         6    11    3.0
# 21             Corolla, North Carolina      15         6     9    5.0
# 22               Waves, North Carolina      14         5    12    6.0
# 23                Selbyville, Delaware      12         5     7    4.5
# 24            Virginia Beach, Virginia      10         4     7    2.0
# 25              Waterford, Connecticut      10         3     8    2.5
#
#     Price (Night)  Price (Total)  \
# 0            1363          10088
# 1            1100           9101
# 2            1875          14978
# 3             845           7130
# 4            1344          11120
# 5            1343          11189
# 6            1250          10556
# 7            1040           8705
# 8            1189           9932
# 9            1013           8578
# 10           1066           8857
# 11           1005           8476
# 12            798           6621
# 13           1226          10081
# 14           1388          11755
# 15           1169           9783
# 16            792           6771
# 17            714           6001
# 18            635           5385
# 19            453           3604
# 20            621           5286
# 21            922           7365
# 22            956           7955
# 23            725           6047
# 24            713           5980
# 25            779           6176
#
#                                                  Link
# 0   https://www.airbnb.com/rooms/54214255?adults=1...
# 1   https://www.airbnb.com/rooms/52596438?adults=1...
# 2   https://www.airbnb.com/rooms/82052743980054013...
# 3   https://www.airbnb.com/rooms/71492911877610115...
# 4   https://www.airbnb.com/rooms/46754338?adults=1...
# 5   https://www.airbnb.com/rooms/78622253239791559...
# 6   https://www.airbnb.com/rooms/20723446?adults=1...
# 7   https://www.airbnb.com/rooms/30565057?adults=1...
# 8   https://www.airbnb.com/rooms/30566829?adults=1...
# 9   https://www.airbnb.com/rooms/49858641?adults=1...
# 10  https://www.airbnb.com/rooms/77905873003528386...
# 11  https://www.airbnb.com/rooms/80819603861655143...
# 12  https://www.airbnb.com/rooms/82114437763820816...
# 13  https://www.airbnb.com/rooms/55623344986455032...
# 14  https://www.airbnb.com/rooms/80286109260585940...
# 15  https://www.airbnb.com/rooms/77177605603439698...
# 16  https://www.airbnb.com/rooms/47076382?adults=1...
# 17  https://www.airbnb.com/rooms/67456193401321541...
# 18  https://www.airbnb.com/rooms/70993488294581605...
# 19  https://www.airbnb.com/rooms/81358806830686400...
# 20  https://www.airbnb.com/rooms/64263514302604527...
# 21  https://www.airbnb.com/rooms/53896063710725562...
# 22  https://www.airbnb.com/rooms/57376839099634327...
# 23  https://www.airbnb.com/rooms/65195642331968100...
# 24  https://www.airbnb.com/rooms/55295609689935839...
# 25  https://www.airbnb.com/rooms/55720803246176804...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 0 to 25
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Name           26 non-null     object
#  1   Location       26 non-null     object
#  2   Guests         26 non-null     int64
#  3   Bedrooms       26 non-null     int64
#  4   Beds           26 non-null     int64
#  5   Baths          26 non-null     float64
#  6   Price (Night)  26 non-null     int64
#  7   Price (Total)  26 non-null     int64
#  8   Link           26 non-null     object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 2.0+ KB

# %%
print('Exporting...')

df.describe().loc[['count', 'mean', 'min', 'max']].to_csv('./exports/describe.csv')
df.to_csv('./exports/available_listings.csv')
